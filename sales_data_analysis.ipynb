# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None

# %% [markdown]
# Generating PySpark Session

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.master("local[*]").appName("Sales Analysis").getOrCreate()

# %% [markdown]
# Import Libraries

# %%
from pyspark.sql.functions import col, when, count, lag, avg, stddev
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression, RandomForestRegressor
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# %% [markdown]
# Load Data

# %%
df = spark.read.csv("./BMW sales data (2010-2024).csv", header=True, inferSchema=True)

# %%
df.printSchema()
# Out:
# root
#  |-- Model: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Color: string (nullable = true)
#  |-- Fuel_Type: string (nullable = true)
#  |-- Transmission: string (nullable = true)
#  |-- Engine_Size_L: double (nullable = true)
#  |-- Mileage_KM: integer (nullable = true)
#  |-- Price_USD: integer (nullable = true)
#  |-- Sales_Volume: integer (nullable = true)
#  |-- Sales_Classification: string (nullable = true)

# %% [markdown]
# EDA

# %%
df.limit(5).toPandas()
df.describe().toPandas()
# Out:
#   summary     Model               Year         Region  Color Fuel_Type  \
# 0   count     50000              50000          50000  50000     50000
# 1    mean      None          2017.0157           None   None      None
# 2  stddev      None  4.324459218093149           None   None      None
# 3     min  3 Series               2010         Africa  Black    Diesel
# 4     max        i8               2024  South America  White    Petrol
#
#   Transmission       Engine_Size_L          Mileage_KM           Price_USD  \
# 0        50000               49999               50000               50000
# 1         None  3.2471749434988695        100307.20314          75034.6009
# 2         None  1.0090878552174578  57941.509343524616  25998.248881722793
# 3    Automatic                 1.5                   3               30000
# 4       Manual                 5.0              199996              119998
#
#          Sales_Volume Sales_Classification
# 0               50000                50000
# 1          5067.51468                 None
# 2  2856.7671252296077                 None
# 3                 100                 High
# 4                9999                  Low

# %%
#null count
nulls = df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]).toPandas()
nulls
# Out:
#    Model  Year  Region  Color  Fuel_Type  Transmission  Engine_Size_L  \
# 0      0     0       0      0          0             0              1
#
#    Mileage_KM  Price_USD  Sales_Volume  Sales_Classification
# 0           0          0             0                     0

# %%
df.show()
# Out:
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |   Model|Year|       Region| Color|Fuel_Type|Transmission|Engine_Size_L|Mileage_KM|Price_USD|Sales_Volume|Sales_Classification|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |5 Series|2016|         Asia|   Red|   Petrol|      Manual|         NULL|    151748|    98740|        8300|                High|
# |      i8|2013|North America|   Red|   Hybrid|   Automatic|          1.6|    121671|    79219|        3428|                 Low|
# |5 Series|2022|North America|  Blue|   Petrol|   Automatic|          4.5|     10991|   113265|        6994|                 Low|
# |      X3|2024|  Middle East|  Blue|   Petrol|   Automatic|          1.7|     27255|    60971|        4047|                 Low|
# |7 Series|2020|South America| Black|   Diesel|      Manual|          2.1|    122131|    49898|        3080|                 Low|
# |5 Series|2017|  Middle East|Silver|   Diesel|      Manual|          1.9|    171362|    42926|        1232|                 Low|
# |      i8|2022|       Europe| White|   Diesel|      Manual|          1.8|    196741|    55064|        7949|                High|
# |      M5|2014|         Asia| Black|   Diesel|   Automatic|          1.6|    121156|   102778|         632|                 Low|
# |      X3|2016|South America| White|   Diesel|   Automatic|          1.7|     48073|   116482|        8944|                High|
# |      i8|2019|       Europe| White| Electric|      Manual|          3.0|     35700|    96257|        4411|                 Low|
# |3 Series|2012|  Middle East| White| Electric|      Manual|          2.4|    101595|   117995|         500|                 Low|
# |      i8|2016|North America|  Blue|   Hybrid|      Manual|          1.9|    116863|    74539|        8252|                High|
# |7 Series|2020|North America|Silver|   Diesel|   Automatic|          3.8|     27403|   100015|        8111|                High|
# |5 Series|2020|       Africa| White| Electric|      Manual|          2.3|    163444|   119486|        4668|                 Low|
# |      X1|2017|         Asia| Black| Electric|   Automatic|          1.6|    107918|    34078|        7291|                High|
# |      M3|2014|North America|Silver|   Hybrid|      Manual|          3.0|    154050|    94997|        7765|                High|
# |      X5|2013|         Asia|  Blue| Electric|      Manual|          2.6|    110142|   114844|        5561|                 Low|
# |      M5|2017|North America|   Red|   Diesel|   Automatic|          2.6|     86900|    81934|        9755|                High|
# |5 Series|2017|North America|Silver| Electric|      Manual|          3.1|     57843|   111326|        4880|                 Low|
# |      X5|2012|       Africa|  Blue| Electric|      Manual|          3.8|    142243|    82677|        7104|                High|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# only showing top 20 rows

# %%
df.show(5)
# Out:
# +--------+----+-------------+-----+---------+------------+-------------+----------+---------+------------+--------------------+
# |   Model|Year|       Region|Color|Fuel_Type|Transmission|Engine_Size_L|Mileage_KM|Price_USD|Sales_Volume|Sales_Classification|
# +--------+----+-------------+-----+---------+------------+-------------+----------+---------+------------+--------------------+
# |5 Series|2016|         Asia|  Red|   Petrol|      Manual|         NULL|    151748|    98740|        8300|                High|
# |      i8|2013|North America|  Red|   Hybrid|   Automatic|          1.6|    121671|    79219|        3428|                 Low|
# |5 Series|2022|North America| Blue|   Petrol|   Automatic|          4.5|     10991|   113265|        6994|                 Low|
# |      X3|2024|  Middle East| Blue|   Petrol|   Automatic|          1.7|     27255|    60971|        4047|                 Low|
# |7 Series|2020|South America|Black|   Diesel|      Manual|          2.1|    122131|    49898|        3080|                 Low|
# +--------+----+-------------+-----+---------+------------+-------------+----------+---------+------------+--------------------+
# only showing top 5 rows

# %%
df.select("Model", "Year").show()
# Out:
# +--------+----+
# |   Model|Year|
# +--------+----+
# |5 Series|2016|
# |      i8|2013|
# |5 Series|2022|
# |      X3|2024|
# |7 Series|2020|
# |5 Series|2017|
# |      i8|2022|
# |      M5|2014|
# |      X3|2016|
# |      i8|2019|
# |3 Series|2012|
# |      i8|2016|
# |7 Series|2020|
# |5 Series|2020|
# |      X1|2017|
# |      M3|2014|
# |      X5|2013|
# |      M5|2017|
# |5 Series|2017|
# |      X5|2012|
# +--------+----+
# only showing top 20 rows

# %%
df.filter(df.Year > 2020).show()
# Out:
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |   Model|Year|       Region| Color|Fuel_Type|Transmission|Engine_Size_L|Mileage_KM|Price_USD|Sales_Volume|Sales_Classification|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |5 Series|2022|North America|  Blue|   Petrol|   Automatic|          4.5|     10991|   113265|        6994|                 Low|
# |      X3|2024|  Middle East|  Blue|   Petrol|   Automatic|          1.7|     27255|    60971|        4047|                 Low|
# |      i8|2022|       Europe| White|   Diesel|      Manual|          1.8|    196741|    55064|        7949|                High|
# |      X5|2021|South America|   Red|   Diesel|      Manual|          2.2|    184981|    47527|        6273|                 Low|
# |      X3|2023|  Middle East| White| Electric|   Automatic|          4.1|    194398|    85370|        4645|                 Low|
# |      M5|2021|         Asia|   Red|   Hybrid|   Automatic|          3.0|    105162|    32076|        9469|                High|
# |      i8|2021|South America|Silver|   Diesel|      Manual|          4.8|      3188|    64577|         448|                 Low|
# |      X1|2022|  Middle East|  Grey|   Hybrid|      Manual|          4.3|    143013|   116432|        4926|                 Low|
# |      M5|2021|South America|  Grey|   Petrol|   Automatic|          3.3|     88342|   108240|        4561|                 Low|
# |      i3|2024|  Middle East|   Red|   Petrol|   Automatic|          3.5|    135958|    69578|         173|                 Low|
# |      X5|2021|       Africa|   Red|   Diesel|      Manual|          3.4|     99697|    60278|        2913|                 Low|
# |      X5|2021|  Middle East| Black|   Petrol|   Automatic|          4.3|     44279|    96256|        7627|                High|
# |      X5|2024|South America| Black|   Hybrid|      Manual|          3.6|    111661|    82675|        2155|                 Low|
# |      i8|2023|       Europe|  Blue|   Diesel|   Automatic|          3.8|     78573|   118317|        7168|                High|
# |      i3|2023|North America|Silver|   Petrol|   Automatic|          4.9|     94453|    79039|        8283|                High|
# |5 Series|2024|         Asia|  Blue| Electric|      Manual|          3.7|    157789|    86855|         648|                 Low|
# |      X6|2023|       Africa| White|   Hybrid|   Automatic|          2.8|     84367|   112542|        7933|                High|
# |      X3|2021|         Asia|Silver|   Hybrid|   Automatic|          3.8|     57759|   119692|        6782|                 Low|
# |3 Series|2021|North America| Black|   Hybrid|   Automatic|          3.9|     87632|    65089|         660|                 Low|
# |3 Series|2023|       Europe| Black| Electric|      Manual|          2.8|    128295|    86402|        4266|                 Low|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# only showing top 20 rows

# %%
df2 = df.withColumn("Vehicle_age", 2024 - col("Year"))

# %%
df2.show()
# Out:
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+-----------+
# |   Model|Year|       Region| Color|Fuel_Type|Transmission|Engine_Size_L|Mileage_KM|Price_USD|Sales_Volume|Sales_Classification|Vehicle_age|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+-----------+
# |5 Series|2016|         Asia|   Red|   Petrol|      Manual|         NULL|    151748|    98740|        8300|                High|          8|
# |      i8|2013|North America|   Red|   Hybrid|   Automatic|          1.6|    121671|    79219|        3428|                 Low|         11|
# |5 Series|2022|North America|  Blue|   Petrol|   Automatic|          4.5|     10991|   113265|        6994|                 Low|          2|
# |      X3|2024|  Middle East|  Blue|   Petrol|   Automatic|          1.7|     27255|    60971|        4047|                 Low|          0|
# |7 Series|2020|South America| Black|   Diesel|      Manual|          2.1|    122131|    49898|        3080|                 Low|          4|
# |5 Series|2017|  Middle East|Silver|   Diesel|      Manual|          1.9|    171362|    42926|        1232|                 Low|          7|
# |      i8|2022|       Europe| White|   Diesel|      Manual|          1.8|    196741|    55064|        7949|                High|          2|
# |      M5|2014|         Asia| Black|   Diesel|   Automatic|          1.6|    121156|   102778|         632|                 Low|         10|
# |      X3|2016|South America| White|   Diesel|   Automatic|          1.7|     48073|   116482|        8944|                High|          8|
# |      i8|2019|       Europe| White| Electric|      Manual|          3.0|     35700|    96257|        4411|                 Low|          5|
# |3 Series|2012|  Middle East| White| Electric|      Manual|          2.4|    101595|   117995|         500|                 Low|         12|
# |      i8|2016|North America|  Blue|   Hybrid|      Manual|          1.9|    116863|    74539|        8252|                High|          8|
# |7 Series|2020|North America|Silver|   Diesel|   Automatic|          3.8|     27403|   100015|        8111|                High|          4|
# |5 Series|2020|       Africa| White| Electric|      Manual|          2.3|    163444|   119486|        4668|                 Low|          4|
# |      X1|2017|         Asia| Black| Electric|   Automatic|          1.6|    107918|    34078|        7291|                High|          7|
# |      M3|2014|North America|Silver|   Hybrid|      Manual|          3.0|    154050|    94997|        7765|                High|         10|
# |      X5|2013|         Asia|  Blue| Electric|      Manual|          2.6|    110142|   114844|        5561|                 Low|         11|
# |      M5|2017|North America|   Red|   Diesel|   Automatic|          2.6|     86900|    81934|        9755|                High|          7|
# |5 Series|2017|North America|Silver| Electric|      Manual|          3.1|     57843|   111326|        4880|                 Low|          7|
# |      X5|2012|       Africa|  Blue| Electric|      Manual|          3.8|    142243|    82677|        7104|                High|         12|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+-----------+
# only showing top 20 rows

# %%
df.groupBy("Region").agg(F.sum("Sales_Volume")).show()
# Out:
# +-------------+-----------------+
# |       Region|sum(Sales_Volume)|
# +-------------+-----------------+
# |       Europe|         42555138|
# |       Africa|         41565252|
# |North America|         42402629|
# |South America|         41551818|
# |  Middle East|         42326620|
# |         Asia|         42974277|
# +-------------+-----------------+

# %%
df.groupBy("Region").agg(
    F.sum("Sales_Volume").alias("Total_Sales")
).toPandas()
# Out:
#           Region  Total_Sales
# 0         Europe     42555138
# 1         Africa     41565252
# 2  North America     42402629
# 3  South America     41551818
# 4    Middle East     42326620
# 5           Asia     42974277

# %% [markdown]
# ✔️ SUM

# %%
df.groupBy("Region").agg(F.sum("Sales_Volume")).show()
# Out:
# +-------------+-----------------+
# |       Region|sum(Sales_Volume)|
# +-------------+-----------------+
# |       Europe|         42555138|
# |       Africa|         41565252|
# |North America|         42402629|
# |South America|         41551818|
# |  Middle East|         42326620|
# |         Asia|         42974277|
# +-------------+-----------------+

# %% [markdown]
# ✔️ AVG (mean)

# %%
df.groupBy("Model").agg(F.avg("Price_USD")).show()
# Out:
# +--------+-----------------+
# |   Model|   avg(Price_USD)|
# +--------+-----------------+
# |      i3|74800.26808142052|
# |3 Series| 75566.2339499456|
# |      X6|74434.60049129075|
# |      X1|75262.21903719913|
# |7 Series|75570.19674239177|
# |      X3|75016.61685568157|
# |5 Series|75287.84407665505|
# |      M5|74474.93099598035|
# |      M3|74841.58871515976|
# |      i8|75366.27095093357|
# |      X5|74708.11678181413|
# +--------+-----------------+

# %% [markdown]
# ✔️ MAX

# %%
df.groupBy("Fuel_Type").agg(F.max("Mileage_KM")).show()
# Out:
# +---------+---------------+
# |Fuel_Type|max(Mileage_KM)|
# +---------+---------------+
# |   Diesel|         199995|
# |   Hybrid|         199996|
# | Electric|         199991|
# |   Petrol|         199987|
# +---------+---------------+

# %% [markdown]
# ✔️ MIN

# %%
df.groupBy("Fuel_Type").agg(F.min("Mileage_KM")).show()
# Out:
# +---------+---------------+
# |Fuel_Type|min(Mileage_KM)|
# +---------+---------------+
# |   Diesel|             42|
# |   Hybrid|             23|
# | Electric|             48|
# |   Petrol|              3|
# +---------+---------------+

# %% [markdown]
# ✔️ COUNT

# %%
df.groupBy("Transmission").agg(F.count("*")).show()
# Out:
# +------------+--------+
# |Transmission|count(1)|
# +------------+--------+
# |   Automatic|   24846|
# |      Manual|   25154|
# +------------+--------+

# %%
df.groupby("Region").agg(F.countDistinct("Model").alias("Total distinct model")).toPandas()
# Out:
#           Region  Total distinct model
# 0         Europe                    11
# 1         Africa                    11
# 2  North America                    11
# 3  South America                    11
# 4    Middle East                    11
# 5           Asia                    11

# %% [markdown]
# Multiple Aggregations at Once

# %%
df.groupBy("Region").agg(
    F.sum("Sales_Volume").alias("Total_Sales"),
    F.avg("Price_USD").alias("Avg_Price"),
    F.countDistinct("Model").alias("Unique_Models")
).toPandas()
# Out:
#           Region  Total_Sales     Avg_Price  Unique_Models
# 0         Europe     42555138  74988.356851             11
# 1         Africa     41565252  74885.771598             11
# 2  North America     42402629  75070.054709             11
# 3  South America     41551818  74973.598837             11
# 4    Middle East     42326620  74726.788487             11
# 5           Asia     42974277  75554.925006             11

# %% [markdown]
# groupBy on multiple columns

# %%
df.groupBy("Region","Fuel_type").agg(
    F.sum("Sales_Volume").alias("Total_Sales")
).toPandas()
# Out:
#            Region Fuel_type  Total_Sales
# 0          Europe    Hybrid     10825662
# 1   South America    Hybrid     10362003
# 2   North America    Hybrid     10808682
# 3   South America    Petrol     10304421
# 4            Asia    Hybrid     11422396
# 5          Africa    Hybrid     10486034
# 6   North America    Petrol     10472845
# 7            Asia    Petrol     10462998
# 8          Europe    Diesel     10406133
# 9          Europe  Electric     10590064
# 10         Africa    Petrol     10538463
# 11         Africa    Diesel     10211670
# 12    Middle East    Petrol     10812148
# 13  North America  Electric     10861198
# 14         Europe    Petrol     10733279
# 15           Asia  Electric     10596850
# 16  North America    Diesel     10259904
# 17    Middle East    Hybrid     10627320
# 18  South America  Electric     10385273
# 19  South America    Diesel     10500121
# 20    Middle East    Diesel     10491957
# 21    Middle East  Electric     10395195
# 22           Asia    Diesel     10492033
# 23         Africa  Electric     10329085

# %% [markdown]
# PIVOT (Very Powerful)

# %%
df.groupBy("Region").pivot("Fuel_Type").agg(
    F.sum("Sales_Volume")
).toPandas()
# Out:
#           Region    Diesel  Electric    Hybrid    Petrol
# 0         Europe  10406133  10590064  10825662  10733279
# 1         Africa  10211670  10329085  10486034  10538463
# 2  North America  10259904  10861198  10808682  10472845
# 3  South America  10500121  10385273  10362003  10304421
# 4    Middle East  10491957  10395195  10627320  10812148
# 5           Asia  10492033  10596850  11422396  10462998

# %% [markdown]
# ORDER Results
#
# Sort results by total sales:

# %%
df.groupBy("Region").agg(
    F.sum("Sales_Volume").alias("Total_Sales")
).orderBy(F.desc("Total_Sales")).toPandas()
# Out:
#           Region  Total_Sales
# 0           Asia     42974277
# 1         Europe     42555138
# 2  North America     42402629
# 3    Middle East     42326620
# 4         Africa     41565252
# 5  South America     41551818

# %% [markdown]
# Filtering Before Aggregation

# %%
df.filter(df.Year > 2020) \
  .groupBy("Region") \
  .agg(F.sum("Sales_Volume").alias("Sales_After_2020")) \
  .show()
# Out:
# +-------------+----------------+
# |       Region|Sales_After_2020|
# +-------------+----------------+
# |       Europe|        11754801|
# |       Africa|        11257467|
# |North America|        11519426|
# |South America|        11018071|
# |  Middle East|        11594599|
# |         Asia|        11457756|
# +-------------+----------------+

# %% [markdown]
# Filtering using SQL Query

# %% [markdown]
# First Create temp view and pass table name ->

# %%
df.createOrReplaceTempView("mytable")

# %%
spark.sql("""
    SELECT *
    FROM mytable
    WHERE Year > 2023
""").toPandas()
# Out:
#          Model  Year         Region   Color Fuel_Type Transmission  \
# 0           X3  2024    Middle East    Blue    Petrol    Automatic
# 1           i3  2024    Middle East     Red    Petrol    Automatic
# 2           X5  2024  South America   Black    Hybrid       Manual
# 3     5 Series  2024           Asia    Blue  Electric       Manual
# 4           X1  2024         Europe     Red    Petrol    Automatic
# ...        ...   ...            ...     ...       ...          ...
# 3422        X3  2024  South America    Blue  Electric    Automatic
# 3423  3 Series  2024         Europe  Silver    Hybrid    Automatic
# 3424        M3  2024         Africa    Blue  Electric    Automatic
# 3425        X3  2024         Europe   White    Petrol       Manual
# 3426        M3  2024           Asia  Silver    Hybrid    Automatic
#
#       Engine_Size_L  Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0               1.7       27255      60971          4047                  Low
# 1               3.5      135958      69578           173                  Low
# 2               3.6      111661      82675          2155                  Low
# 3               3.7      157789      86855           648                  Low
# 4               2.7       24141      84346          4289                  Low
# ...             ...         ...        ...           ...                  ...
# 3422            2.6       11446      51398          5395                  Low
# 3423            1.9       76618      92351          4427                  Low
# 3424            2.8       86228      38003          5911                  Low
# 3425            2.8       44683      33558          2601                  Low
# 3426            1.7      198846      85034          7888                 High
#
# [3427 rows x 11 columns]

# %%
windowSpec = Window.partitionBy("Region").orderBy("Year")
windowSpec

# %%
df2 = df.withColumn("RowNum", F.row_number().over(windowSpec)) \
        .withColumn("PrevSales", F.lag("Sales_Volume").over(windowSpec)) \
        .withColumn("NextSales", F.lead("Sales_Volume").over(windowSpec)) \
        .withColumn("RunningTotal", F.sum("Sales_Volume").over(windowSpec)) \
        .withColumn("Rank", F.rank().over(windowSpec))

df2.show(6)
# Out:
# +-----+----+------+------+---------+------------+-------------+----------+---------+------------+--------------------+------+---------+---------+------------+----+
# |Model|Year|Region| Color|Fuel_Type|Transmission|Engine_Size_L|Mileage_KM|Price_USD|Sales_Volume|Sales_Classification|RowNum|PrevSales|NextSales|RunningTotal|Rank|
# +-----+----+------+------+---------+------------+-------------+----------+---------+------------+--------------------+------+---------+---------+------------+----+
# |   X6|2010|Africa|Silver|   Petrol|      Manual|          1.7|    176650|    33796|        5935|                 Low|     1|     NULL|     7607|     2855044|   1|
# |   i3|2010|Africa|  Blue|   Petrol|      Manual|          3.6|     91061|    45834|        7607|                High|     2|     5935|      968|     2855044|   1|
# |   i3|2010|Africa|  Blue|   Diesel|      Manual|          1.8|    120482|   101137|         968|                 Low|     3|     7607|     5236|     2855044|   1|
# |   X5|2010|Africa| Black|   Diesel|   Automatic|          2.2|    187108|   105887|        5236|                 Low|     4|      968|     1252|     2855044|   1|
# |   X1|2010|Africa|  Grey|   Diesel|   Automatic|          1.6|    100516|    49598|        1252|                 Low|     5|     5236|     8358|     2855044|   1|
# |   X5|2010|Africa| White|   Hybrid|   Automatic|          2.4|     23577|    62344|        8358|                High|     6|     1252|     2849|     2855044|   1|
# +-----+----+------+------+---------+------------+-------------+----------+---------+------------+--------------------+------+---------+---------+------------+----+
# only showing top 6 rows

# %% [markdown]
# by default .show() -> prints 20 rows

# %% [markdown]
# 🟦 STEP 1 — TRANSFORMATIONS IN PYSPARK

# %% [markdown]
# 🎯 1. select() – choose columns

# %%
df.select("Color", "Price_USD").show()
# Out:
# +------+---------+
# | Color|Price_USD|
# +------+---------+
# |   Red|    98740|
# |   Red|    79219|
# |  Blue|   113265|
# |  Blue|    60971|
# | Black|    49898|
# |Silver|    42926|
# | White|    55064|
# | Black|   102778|
# | White|   116482|
# | White|    96257|
# | White|   117995|
# |  Blue|    74539|
# |Silver|   100015|
# | White|   119486|
# | Black|    34078|
# |Silver|    94997|
# |  Blue|   114844|
# |   Red|    81934|
# |Silver|   111326|
# |  Blue|    82677|
# +------+---------+
# only showing top 20 rows

# %% [markdown]
# 🎯 2. selectExpr() – SQL inside select

# %%
df.selectExpr("Model", "Year", "Price_USD * 86 AS Price_INR").show()
# Out:
# +--------+----+---------+
# |   Model|Year|Price_INR|
# +--------+----+---------+
# |5 Series|2016|  8491640|
# |      i8|2013|  6812834|
# |5 Series|2022|  9740790|
# |      X3|2024|  5243506|
# |7 Series|2020|  4291228|
# |5 Series|2017|  3691636|
# |      i8|2022|  4735504|
# |      M5|2014|  8838908|
# |      X3|2016| 10017452|
# |      i8|2019|  8278102|
# |3 Series|2012| 10147570|
# |      i8|2016|  6410354|
# |7 Series|2020|  8601290|
# |5 Series|2020| 10275796|
# |      X1|2017|  2930708|
# |      M3|2014|  8169742|
# |      X5|2013|  9876584|
# |      M5|2017|  7046324|
# |5 Series|2017|  9574036|
# |      X5|2012|  7110222|
# +--------+----+---------+
# only showing top 20 rows

# %% [markdown]
# 🎯 3. filter() – filter rows

# %%
df.filter(df["Color"] == "Red").show()
# Out:
# +--------+----+-------------+-----+---------+------------+-------------+----------+---------+------------+--------------------+
# |   Model|Year|       Region|Color|Fuel_Type|Transmission|Engine_Size_L|Mileage_KM|Price_USD|Sales_Volume|Sales_Classification|
# +--------+----+-------------+-----+---------+------------+-------------+----------+---------+------------+--------------------+
# |5 Series|2016|         Asia|  Red|   Petrol|      Manual|         NULL|    151748|    98740|        8300|                High|
# |      i8|2013|North America|  Red|   Hybrid|   Automatic|          1.6|    121671|    79219|        3428|                 Low|
# |      M5|2017|North America|  Red|   Diesel|   Automatic|          2.6|     86900|    81934|        9755|                High|
# |      X3|2015|North America|  Red|   Diesel|   Automatic|          3.7|    123910|    88091|        8635|                High|
# |      X5|2021|South America|  Red|   Diesel|      Manual|          2.2|    184981|    47527|        6273|                 Low|
# |      M3|2015|         Asia|  Red|   Hybrid|      Manual|          2.0|     41514|   116902|        8897|                High|
# |      M5|2021|         Asia|  Red|   Hybrid|   Automatic|          3.0|    105162|    32076|        9469|                High|
# |      M5|2019|         Asia|  Red|   Diesel|      Manual|          2.1|     97294|    53277|        4091|                 Low|
# |      i3|2024|  Middle East|  Red|   Petrol|   Automatic|          3.5|    135958|    69578|         173|                 Low|
# |      X5|2021|       Africa|  Red|   Diesel|      Manual|          3.4|     99697|    60278|        2913|                 Low|
# |      i3|2018|South America|  Red|   Petrol|      Manual|          4.1|      1428|    46127|         608|                 Low|
# |      i8|2012|  Middle East|  Red|   Diesel|   Automatic|          3.2|    110845|   100747|        3291|                 Low|
# |      M5|2014|South America|  Red| Electric|   Automatic|          4.2|    125379|    96739|        3754|                 Low|
# |      M3|2014|       Europe|  Red| Electric|      Manual|          2.5|     74474|    65464|        9390|                High|
# |      X6|2018|         Asia|  Red| Electric|      Manual|          2.3|     10027|    89970|        4935|                 Low|
# |      M3|2011|         Asia|  Red|   Diesel|   Automatic|          3.7|     40915|    44322|        2191|                 Low|
# |5 Series|2011|  Middle East|  Red|   Hybrid|   Automatic|          3.1|    139212|    31815|        2011|                 Low|
# |7 Series|2013|         Asia|  Red|   Hybrid|      Manual|          4.5|    144832|   118363|        1564|                 Low|
# |      i3|2021|South America|  Red| Electric|      Manual|          4.6|    107985|    43355|         945|                 Low|
# |      X1|2024|       Europe|  Red|   Petrol|   Automatic|          2.7|     24141|    84346|        4289|                 Low|
# +--------+----+-------------+-----+---------+------------+-------------+----------+---------+------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# OR using SQL-style string:

# %%
df.filter("Year > 2022").show()
# Out:
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |   Model|Year|       Region| Color|Fuel_Type|Transmission|Engine_Size_L|Mileage_KM|Price_USD|Sales_Volume|Sales_Classification|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |      X3|2024|  Middle East|  Blue|   Petrol|   Automatic|          1.7|     27255|    60971|        4047|                 Low|
# |      X3|2023|  Middle East| White| Electric|   Automatic|          4.1|    194398|    85370|        4645|                 Low|
# |      i3|2024|  Middle East|   Red|   Petrol|   Automatic|          3.5|    135958|    69578|         173|                 Low|
# |      X5|2024|South America| Black|   Hybrid|      Manual|          3.6|    111661|    82675|        2155|                 Low|
# |      i8|2023|       Europe|  Blue|   Diesel|   Automatic|          3.8|     78573|   118317|        7168|                High|
# |      i3|2023|North America|Silver|   Petrol|   Automatic|          4.9|     94453|    79039|        8283|                High|
# |5 Series|2024|         Asia|  Blue| Electric|      Manual|          3.7|    157789|    86855|         648|                 Low|
# |      X6|2023|       Africa| White|   Hybrid|   Automatic|          2.8|     84367|   112542|        7933|                High|
# |3 Series|2023|       Europe| Black| Electric|      Manual|          2.8|    128295|    86402|        4266|                 Low|
# |      X1|2024|       Europe|   Red|   Petrol|   Automatic|          2.7|     24141|    84346|        4289|                 Low|
# |      M5|2024|North America| Black|   Diesel|      Manual|          2.7|    143885|    90388|        7944|                High|
# |7 Series|2023|North America|  Grey|   Diesel|   Automatic|          4.8|     64153|   117121|        4823|                 Low|
# |      X3|2023|       Europe|   Red|   Hybrid|      Manual|          3.0|     12922|   101473|        8030|                High|
# |      X5|2024|         Asia|  Blue|   Hybrid|   Automatic|          2.6|    120597|    95900|        8581|                High|
# |      i3|2023|       Africa|  Grey|   Hybrid|      Manual|          1.8|     73990|    89587|        6301|                 Low|
# |      X1|2023|  Middle East|Silver|   Diesel|      Manual|          2.0|    172729|    85801|        8644|                High|
# |7 Series|2024|North America|  Grey| Electric|      Manual|          2.4|     80659|    92213|        5456|                 Low|
# |7 Series|2024|       Africa|  Blue|   Diesel|   Automatic|          3.1|    132686|    42013|        8472|                High|
# |7 Series|2023|       Europe|   Red| Electric|      Manual|          5.0|     50602|    83812|        2241|                 Low|
# |      i3|2023|North America|Silver| Electric|      Manual|          5.0|    190643|    36081|         190|                 Low|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# 🎯 4. where() – same as filter

# %%
df.where(df.Region == "Asia").show()
# Out:
# +--------+----+------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |   Model|Year|Region| Color|Fuel_Type|Transmission|Engine_Size_L|Mileage_KM|Price_USD|Sales_Volume|Sales_Classification|
# +--------+----+------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |5 Series|2016|  Asia|   Red|   Petrol|      Manual|         NULL|    151748|    98740|        8300|                High|
# |      M5|2014|  Asia| Black|   Diesel|   Automatic|          1.6|    121156|   102778|         632|                 Low|
# |      X1|2017|  Asia| Black| Electric|   Automatic|          1.6|    107918|    34078|        7291|                High|
# |      X5|2013|  Asia|  Blue| Electric|      Manual|          2.6|    110142|   114844|        5561|                 Low|
# |      M3|2015|  Asia|   Red|   Hybrid|      Manual|          2.0|     41514|   116902|        8897|                High|
# |      M5|2021|  Asia|   Red|   Hybrid|   Automatic|          3.0|    105162|    32076|        9469|                High|
# |      M3|2014|  Asia| White| Electric|   Automatic|          3.8|     90282|    64049|        1440|                 Low|
# |      M5|2019|  Asia|   Red|   Diesel|      Manual|          2.1|     97294|    53277|        4091|                 Low|
# |      i8|2015|  Asia| White|   Hybrid|   Automatic|          2.4|    194395|   118788|        3384|                 Low|
# |5 Series|2024|  Asia|  Blue| Electric|      Manual|          3.7|    157789|    86855|         648|                 Low|
# |      i3|2012|  Asia| White|   Hybrid|      Manual|          3.9|    193905|    93508|        8438|                High|
# |      X3|2021|  Asia|Silver|   Hybrid|   Automatic|          3.8|     57759|   119692|        6782|                 Low|
# |      X6|2018|  Asia|   Red| Electric|      Manual|          2.3|     10027|    89970|        4935|                 Low|
# |      M3|2011|  Asia|   Red|   Diesel|   Automatic|          3.7|     40915|    44322|        2191|                 Low|
# |      X3|2019|  Asia|Silver| Electric|   Automatic|          4.2|     88705|   111352|        1932|                 Low|
# |7 Series|2013|  Asia|   Red|   Hybrid|      Manual|          4.5|    144832|   118363|        1564|                 Low|
# |      i3|2015|  Asia|Silver| Electric|      Manual|          3.5|     68161|    63696|        7218|                High|
# |      X6|2022|  Asia| White| Electric|      Manual|          1.9|    182027|    35951|        3389|                 Low|
# |      X5|2024|  Asia|  Blue|   Hybrid|   Automatic|          2.6|    120597|    95900|        8581|                High|
# |      X1|2021|  Asia|Silver|   Diesel|      Manual|          2.6|     84621|   119897|        4601|                 Low|
# +--------+----+------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# 🎯 5. drop() – remove columns

# %%
df.drop("Mileage_KM", "Color").show()
# Out:
# +--------+----+-------------+---------+------------+-------------+---------+------------+--------------------+
# |   Model|Year|       Region|Fuel_Type|Transmission|Engine_Size_L|Price_USD|Sales_Volume|Sales_Classification|
# +--------+----+-------------+---------+------------+-------------+---------+------------+--------------------+
# |5 Series|2016|         Asia|   Petrol|      Manual|         NULL|    98740|        8300|                High|
# |      i8|2013|North America|   Hybrid|   Automatic|          1.6|    79219|        3428|                 Low|
# |5 Series|2022|North America|   Petrol|   Automatic|          4.5|   113265|        6994|                 Low|
# |      X3|2024|  Middle East|   Petrol|   Automatic|          1.7|    60971|        4047|                 Low|
# |7 Series|2020|South America|   Diesel|      Manual|          2.1|    49898|        3080|                 Low|
# |5 Series|2017|  Middle East|   Diesel|      Manual|          1.9|    42926|        1232|                 Low|
# |      i8|2022|       Europe|   Diesel|      Manual|          1.8|    55064|        7949|                High|
# |      M5|2014|         Asia|   Diesel|   Automatic|          1.6|   102778|         632|                 Low|
# |      X3|2016|South America|   Diesel|   Automatic|          1.7|   116482|        8944|                High|
# |      i8|2019|       Europe| Electric|      Manual|          3.0|    96257|        4411|                 Low|
# |3 Series|2012|  Middle East| Electric|      Manual|          2.4|   117995|         500|                 Low|
# |      i8|2016|North America|   Hybrid|      Manual|          1.9|    74539|        8252|                High|
# |7 Series|2020|North America|   Diesel|   Automatic|          3.8|   100015|        8111|                High|
# |5 Series|2020|       Africa| Electric|      Manual|          2.3|   119486|        4668|                 Low|
# |      X1|2017|         Asia| Electric|   Automatic|          1.6|    34078|        7291|                High|
# |      M3|2014|North America|   Hybrid|      Manual|          3.0|    94997|        7765|                High|
# |      X5|2013|         Asia| Electric|      Manual|          2.6|   114844|        5561|                 Low|
# |      M5|2017|North America|   Diesel|   Automatic|          2.6|    81934|        9755|                High|
# |5 Series|2017|North America| Electric|      Manual|          3.1|   111326|        4880|                 Low|
# |      X5|2012|       Africa| Electric|      Manual|          3.8|    82677|        7104|                High|
# +--------+----+-------------+---------+------------+-------------+---------+------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# 🎯 7. cast() – change data type

# %%
df.withColumn("Year", col("Year").cast("int")).printSchema()
# Out:
# root
#  |-- Model: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Color: string (nullable = true)
#  |-- Fuel_Type: string (nullable = true)
#  |-- Transmission: string (nullable = true)
#  |-- Engine_Size_L: double (nullable = true)
#  |-- Mileage_KM: integer (nullable = true)
#  |-- Price_USD: integer (nullable = true)
#  |-- Sales_Volume: integer (nullable = true)
#  |-- Sales_Classification: string (nullable = true)

# %% [markdown]
# 🎯 8. withColumnRenamed() – rename column

# %%
df.withColumnRenamed("Engine_Size_L", "Engine_Liters").show()
# Out:
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |   Model|Year|       Region| Color|Fuel_Type|Transmission|Engine_Liters|Mileage_KM|Price_USD|Sales_Volume|Sales_Classification|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |5 Series|2016|         Asia|   Red|   Petrol|      Manual|         NULL|    151748|    98740|        8300|                High|
# |      i8|2013|North America|   Red|   Hybrid|   Automatic|          1.6|    121671|    79219|        3428|                 Low|
# |5 Series|2022|North America|  Blue|   Petrol|   Automatic|          4.5|     10991|   113265|        6994|                 Low|
# |      X3|2024|  Middle East|  Blue|   Petrol|   Automatic|          1.7|     27255|    60971|        4047|                 Low|
# |7 Series|2020|South America| Black|   Diesel|      Manual|          2.1|    122131|    49898|        3080|                 Low|
# |5 Series|2017|  Middle East|Silver|   Diesel|      Manual|          1.9|    171362|    42926|        1232|                 Low|
# |      i8|2022|       Europe| White|   Diesel|      Manual|          1.8|    196741|    55064|        7949|                High|
# |      M5|2014|         Asia| Black|   Diesel|   Automatic|          1.6|    121156|   102778|         632|                 Low|
# |      X3|2016|South America| White|   Diesel|   Automatic|          1.7|     48073|   116482|        8944|                High|
# |      i8|2019|       Europe| White| Electric|      Manual|          3.0|     35700|    96257|        4411|                 Low|
# |3 Series|2012|  Middle East| White| Electric|      Manual|          2.4|    101595|   117995|         500|                 Low|
# |      i8|2016|North America|  Blue|   Hybrid|      Manual|          1.9|    116863|    74539|        8252|                High|
# |7 Series|2020|North America|Silver|   Diesel|   Automatic|          3.8|     27403|   100015|        8111|                High|
# |5 Series|2020|       Africa| White| Electric|      Manual|          2.3|    163444|   119486|        4668|                 Low|
# |      X1|2017|         Asia| Black| Electric|   Automatic|          1.6|    107918|    34078|        7291|                High|
# |      M3|2014|North America|Silver|   Hybrid|      Manual|          3.0|    154050|    94997|        7765|                High|
# |      X5|2013|         Asia|  Blue| Electric|      Manual|          2.6|    110142|   114844|        5561|                 Low|
# |      M5|2017|North America|   Red|   Diesel|   Automatic|          2.6|     86900|    81934|        9755|                High|
# |5 Series|2017|North America|Silver| Electric|      Manual|          3.1|     57843|   111326|        4880|                 Low|
# |      X5|2012|       Africa|  Blue| Electric|      Manual|          3.8|    142243|    82677|        7104|                High|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# 🎯 9. dropDuplicates() – remove duplicate rows

# %%
df.dropDuplicates(["Model", "Year"]).show()
# Out:
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |   Model|Year|       Region| Color|Fuel_Type|Transmission|Engine_Size_L|Mileage_KM|Price_USD|Sales_Volume|Sales_Classification|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# |3 Series|2010|         Asia| Black|   Petrol|      Manual|          2.1|    107572|    86660|        8650|                High|
# |3 Series|2011|  Middle East|   Red|   Hybrid|   Automatic|          4.0|     22280|    55612|        6698|                 Low|
# |3 Series|2012|  Middle East| White| Electric|      Manual|          2.4|    101595|   117995|         500|                 Low|
# |3 Series|2013|South America| Black| Electric|   Automatic|          2.3|    173100|   101189|        1476|                 Low|
# |3 Series|2014|  Middle East|  Grey|   Diesel|      Manual|          4.9|    154711|    76421|         867|                 Low|
# |3 Series|2015|       Europe|   Red|   Hybrid|      Manual|          2.4|    191042|    89156|        7342|                High|
# |3 Series|2016|       Europe| White| Electric|   Automatic|          4.7|    149253|    71328|        3222|                 Low|
# |3 Series|2017|       Europe|  Grey|   Petrol|      Manual|          3.8|     89365|    86684|        9474|                High|
# |3 Series|2018|       Africa| Black| Electric|      Manual|          1.8|    117061|    54762|        3293|                 Low|
# |3 Series|2019|South America|Silver|   Hybrid|      Manual|          2.8|    193021|    44950|        1703|                 Low|
# |3 Series|2020|North America|Silver|   Hybrid|   Automatic|          3.0|    158046|    78509|        8070|                High|
# |3 Series|2021|North America| Black|   Hybrid|   Automatic|          3.9|     87632|    65089|         660|                 Low|
# |3 Series|2022|South America|   Red| Electric|   Automatic|          3.6|     68978|   107968|        4129|                 Low|
# |3 Series|2023|       Europe| Black| Electric|      Manual|          2.8|    128295|    86402|        4266|                 Low|
# |3 Series|2024|South America|  Grey|   Hybrid|   Automatic|          3.2|    144152|    49557|        1180|                 Low|
# |5 Series|2010|       Europe|   Red|   Petrol|      Manual|          1.8|    194101|    34120|        1344|                 Low|
# |5 Series|2011|  Middle East|   Red|   Hybrid|   Automatic|          3.1|    139212|    31815|        2011|                 Low|
# |5 Series|2012|         Asia|   Red|   Diesel|   Automatic|          2.7|    124260|    39501|        6584|                 Low|
# |5 Series|2013|         Asia|  Blue|   Hybrid|   Automatic|          3.8|     45722|    74501|        6935|                 Low|
# |5 Series|2014|South America| Black|   Diesel|   Automatic|          4.2|    134531|    87621|        4611|                 Low|
# +--------+----+-------------+------+---------+------------+-------------+----------+---------+------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# 🎯 10. distinct() – unique rows

# %% [markdown]
# df.select("Region").distinct().show()
